# %% [markdown]
# # Importing data

# %%
import pandas as pd
import numpy as np
import os

# %%
# Folder Path
path = r'/Users/gil/Documents/06-2023 Instacart Basket Analysis New'

# %% [markdown]
# # Importing datasets

# %%
#import df_orders_products_combined
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
#import df_products_checked
df_products_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_products_checked.shape
# Out:
# (49672, 6)

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  number_of_days_since_prior_order  product_id  \
# 0                  8                               NaN         196
# 1                  8                               NaN       14084
# 2                  8                               NaN       12427
# 3                  8                               NaN       26088
# 4                  8                               NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# ### Product ID is the hey here, as it appears in both dataframes, so I'd use df.merge() function, as the dataframes are of different sizes.

# %%
#Drop the Merge column due to error: Cannot use name of an existing column for indicator column
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
df_merged = df_orders_products_combined.merge(df_products_checked, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  number_of_days_since_prior_order  product_id  \
# 0                  8                               NaN         196
# 1                  7                              15.0         196
# 2                 12                              21.0         196
# 3                  7                              29.0         196
# 4                 15                              28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# 0                  1          0           195         Soda        77
# ...

# %%
#Drop column 1
df_merged = df_merged.drop(columns = ['Unnamed: 0_x'])

# %%
df_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  number_of_days_since_prior_order  product_id  \
# 0                         8                               NaN         196
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
